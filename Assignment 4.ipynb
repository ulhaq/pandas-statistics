# %% [markdown]
# *All functions are defined in module.py*

# %%
# %matplotlib notebook
from module import *

download_extract('http://api.worldbank.org/v2/en/indicator/SI.POV.DDAY?downloadformat=csv')
# Out:
# {'Date': 'Sat, 09 Mar 2019 17:00:58 GMT', 'Content-Type': 'application/zip', 'Content-Length': '18011', 'Connection': 'keep-alive', 'Content-Disposition': 'attachment; filename=API_SI.POV.DDAY_DS2_en_csv_v2_10474275.zip', 'X-Powered-By': 'ASP.NET', 'Set-Cookie': 'TS01fa65e4=01359ee976ff1116c9c73fd76eeeebde92386e24f14740fa145fc14ef7ec99911044c00cef; Path=/', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'deny'}
# -----------------
# Downloaded API_SI.POV.DDAY_DS2_en_csv_v2_10474275.zip

# %% [markdown]
# # Task 1

# %% [markdown]
# This will show a line chart of the development in poverty over time in Argentina, Ivory Coast and USA.

# %%
get_poverty(['ARG', 'CIV', 'USA']).plot(figsize=(10,5), title="Development in poverty over time in Argentina, Ivory Coast and USA").set_ylabel('Poverty rate in percentage')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0, 0.5, 'Poverty rate in percentage')

# %% [markdown]
# # Task 2

# %% [markdown]
# This will show a bar chart of top 10 countries with the highest poverty rate in a specified year.

# %%
year = '2016'

top_10_poverty_countries(year).plot.bar(figsize=(10,5), x="Country Name", title=f"Top 10 countries with the highest poverty rate in {year}").set_ylabel('Poverty rate in percentage')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0, 0.5, 'Poverty rate in percentage')

# %% [markdown]
# # Task 3

# %% [markdown]
# This will show a line chart of the development in poverty over time in Central America.
#
# I think that a line chart can nicely describe the development in poverty over time. However I could have used a world map with subplots as I've done in Task 4.

# %%
get_poverty(['BLZ', 'CRI', 'SLV', 'GTM', 'HND', 'NIC', 'PAN']).plot(figsize=(10,5), title="Development in poverty over time in Central America").set_ylabel('Poverty rate in percentage')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0, 0.5, 'Poverty rate in percentage')

# %% [markdown]
# # Task 4

# %% [markdown]
# This will show two maps for individuals using the Internet in some European countries
#
# This comparison can be helpful to determine countries which are in the first row with regards to adopting IT, and how the countries have changed their usage of Internet over time.

# %%
download_extract('http://api.worldbank.org/v2/en/indicator/IT.NET.USER.ZS?downloadformat=csv')

fig, ax = plt.subplots(ncols=2)
fig.suptitle("Individuals using the Internet in some European countries")

year1 = '2016'
year2 = '2000'
country_codes = ['AUT', 'BEL', 'DEU', 'DNK', 'ESP', 'FIN', 'GBR', 'GRC', 'HUN', 'ITA', 'LUX', 'NLD', 'POL', 'PRT', 'SWE']

ax[0].set_title(f"in {year1}")
ax[1].set_title(f"in {year2}")

it_2016 = get_internet_for_country(year1, country_codes)
it_2005 = get_internet_for_country(year2, country_codes)

it_2016.plot(ax=ax[0], column=year1, legend=True, cmap='OrRd')
it_2005.plot(ax=ax[1], column=year2, legend=True, cmap='OrRd')
# Out:
# {'Date': 'Sat, 09 Mar 2019 17:00:59 GMT', 'Content-Type': 'application/zip', 'Content-Length': '55683', 'Connection': 'keep-alive', 'Content-Disposition': 'attachment; filename=API_IT.NET.USER.ZS_DS2_en_csv_v2_10475039.zip', 'X-Powered-By': 'ASP.NET', 'Set-Cookie': 'TS01fa65e4=01359ee976bfa737f679a268583adcaf4334b91fb1417e0a4726f25c5123ce543419dbe50a; Path=/', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'deny'}
# -----------------
# Downloaded API_IT.NET.USER.ZS_DS2_en_csv_v2_10475039.zip
# <img src="data:image/png;base64,..." width="640">
